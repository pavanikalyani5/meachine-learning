# %%
# Import Libraries
import pandas as pd 
import numpy as np 
import surprise
from surprise.accuracy import rmse
from matplotlib import pyplot as plt

# %%
# Load Dataset
movies_df = pd.read_csv('./movie_ratings.csv')
movies_df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# Preprocessing

# Remove timestamp column
movies_df = movies_df.drop('timestamp', axis=1)
movies_df.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
# Dataset Description
num_users = movies_df.userId.unique().shape[0]
num_movies = movies_df.movieId.unique().shape[0]
num_ratings = movies_df.shape[0]

print('Number of Users: {}'.format(num_users))
print('Number of Movies: {}'.format(num_movies))
print('Number of Ratings: {}'.format(num_ratings))
# Out:
# Number of Users: 610
# Number of Movies: 9724
# Number of Ratings: 100836

# %%
# Range of Movie Ratings
lower_rating = movies_df['rating'].min()
upper_rating = movies_df['rating'].max()
print('Rating ranges from {} to {}'.format(lower_rating, upper_rating))
# Out:
# Rating ranges from 0.5 to 5.0

# %%
# Load dataset into surprise
reader = surprise.Reader(rating_scale=(0.5, 5.0))
data = surprise.Dataset.load_from_df(movies_df, reader)

# %%
from surprise.model_selection import train_test_split

# Train-Test Split ratio
split = 0.2

train, test = train_test_split(data, test_size=split)

# %% [markdown]
# ## 1. User User filtering

# %%
# User-User

def get_user_user_predictions(train, test, k):
    
    # K Nearest Neighbours
    K = k # Ranges from 1 to NUM_USERS

    # Configuration for similarity measure
    # PARAM: name takes values {'cosine', 'pearson'}
    # PARAM: user_based takes values {'True', 'False'}  If set to false then similarity is taken between items.
    options = {
        'name': 'cosine',
        'user_based': True
    }

    # Find user-user similarities
    obj = surprise.prediction_algorithms.KNNWithMeans(k=K, sim_options=options)
    output = obj.fit(train)

    # Predict on test dataset
    uu_predictions = obj.test(test)
    rmse(uu_predictions)
    return uu_predictions

# %%
uu_predictions = get_user_user_predictions(train, test, 10)
print(uu_predictions)

# in the result, Prediction(uid=x, iid=y) means item y is recommended for user x
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9044
# [Prediction(uid=241, iid=296, r_ui=4.5, est=3.9548671984253585, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=474, iid=7090, r_ui=4.0, est=3.620950441756016, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=51, iid=3681, r_ui=4.0, est=4.212922702501518, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=95, iid=6288, r_ui=4.0, est=4.487888144141617, details={'was_impossible': False, 'actual_k': 2}), Prediction(uid=66, iid=3252, r_ui=4.5, est=4.3019467787424714, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=260, iid=7361, r_ui=3.5, est=4.278190071940799, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=424, iid=1092, r_ui=4.0, est=2.9713226717799146, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=592, iid=589, r_ui=5.0, est=3.80781462840959, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=391, iid=3176, r_ui=3.0, est=3.841834830539562, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=524, iid=839, r_ui=3.0, est=2.416754298489484, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=482, iid=1784, r_ui=3.0, est=3.8330588727301533, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=221, iid=1663, r_ui=3.5, est=4.325125769221264, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=325, iid=1279, r_ui=4.0, est=4.455274303830916, details={'was_impossible': False, 'actual_k': 6}), Prediction(uid=603, iid=1291, r_ui=3.0, est=3.7268730731755886, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=448, iid=109042, r_ui=2.0, est=1.6566955449991174, details={'was_impossible': False, 'actual_k': 1}), Prediction(uid=599, iid=85796, r_ui=2.5, est=1.534001157941362, details={'was_impossible': False, 'actual_k': 3}), Prediction(uid=132, iid=6863, r_ui=4.0, est=2.5745161895249837, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=573, iid=3785, r_ui=4.5, est=3.585926650875627, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=125, iid=78218, r_ui=3.0, est=3.5002851192542273, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}), Prediction(uid=599, iid=1663, r_ui=2.5, est=2.779499698326341, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=104, iid=2153, r_ui=2.0, est=2.8141103181976477, details={'was_impossible': False, 'actual_k': 9}), Prediction(uid=489, iid=3742, r_ui=4.5, est=3.0176426336444377, details={'was_impossible': False, 'actual_k': 8}), Prediction(uid=387, iid=2356, r_ui=3.0, est=2.3860427204074015, details={'was_impossible': False, 'actual_k': 4}), Prediction(uid=368, iid=3102, r_ui=3.0, est=2.9160795593917945, details={'was_impossible': False, 'actual_k': 5}), Prediction(uid=200, iid=3489, r_ui=3.0, est=3.738625888678057, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=410, iid=3928, r_ui=5.0, est=3.8948540393341404, details={'was_impossible': False, 'actual_k': 3}), Prediction(uid=302, iid=36, r_ui=4.0, est=4.242782351472045, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=345, iid=4792, r_ui=3.0, est=4.126507140826489, details={'was_impossible': False, 'actual_k': 2}), Prediction(uid=136, iid=293, r_ui=1.0, est=3.518613789955533, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=139, iid=5816, r_ui=3.0, est=2.6557882697689275, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=365, iid=46578, r_ui=2.5, est=3.311416297335006, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=232, iid=50005, r_ui=3.0, est=2.8697313237221493, details={'was_impossible': False, 'actual_k': 1}), Prediction(uid=414, iid=7366, r_ui=3.0, est=3.0761089034998634, details={'was_impossible': False, 'actual_k': 6}), Prediction(uid=608, iid=3785, r_ui=2.5, est=2.6223522094709866, details={'was_impossible': False, 'actual_k': 10}), Prediction(uid=483, iid=47, r_ui=3.5, est=3.6886360177104525, de ...

# %% [markdown]
# ## 2. SVD Decomposition

# %%
algo = surprise.SVD()
algo.fit(train)
predictions = algo.test(test)

# %%
rmse(predictions)
# Out:
# RMSE: 0.8655
# 0.8654560359451237
